# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("clean_df3.csv")
df
# Out:
#       age  is_female  bmi  children  is_smoker  charges  region_northwest  \
# 0      19          1   27         0          1    16884                 0
# 1      18          0   33         1          0     1725                 0
# 2      28          0   33         3          0     4449                 0
# 3      33          0   22         0          0    21984                 1
# 4      32          0   28         0          0     3866                 1
# ...   ...        ...  ...       ...        ...      ...               ...
# 1332   50          0   30         3          0    10600                 1
# 1333   18          1   31         0          0     2205                 0
# 1334   18          1   36         0          0     1629                 0
# 1335   21          1   25         0          0     2007                 0
# 1336   61          1   29         0          1    29141                 1
#
#       region_southeast  region_southwest  bmi_category_normal  \
# ...

# %%
df.dtypes
# Out:
# age                        float64
# is_female                    int64
# bmi                        float64
# children                   float64
# is_smoker                    int64
# charges                      int64
# region_northwest             int64
# region_southeast             int64
# region_southwest             int64
# bmi_category_normal          int64
# bmi_category_overweight      int64
# bmi_category_obese           int64
# charges_bin                  int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
X = df.drop(['charges'],axis = 1)
y = df['charges']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
age	= int(input("inter your Age"))
bmi	= float(input("inter your Bmi"))
is_female = float(input("inter your Gender"))
children= float(input("inter your children"))
is_smoker = float(input("inter your smoke"))

region_northwest =	int(input("north west"))
region_southeast	=int(input("region south east"))
region_southwest	=int(input("region south west"))
bmi_category_normal =int(input("inter BMI_NORMAL"))
bmi_category_overweight =int(input("inter BMI OVERWEIGHT"))
bmi_category_obese =int(input("inter BMI OBESE"))


new_data = [[age,bmi,is_female,children,is_smoker,region_northwest,	region_southeast,region_southwest
             ,bmi_category_normal,bmi_category_overweight,bmi_category_obese]]


y_pred = model.predict(new_data)


print(f"Predict Insurance Charges: {y_pred[0]:.2f}")
# Out:
# inter your Age 30
# inter your Bmi 35
# inter your Gender 1
# inter your children 1
# inter your smoke 1
# north west 1
# region south east 1
# region south west 1
# inter BMI_NORMAL 1
# inter BMI OVERWEIGHT 1
# inter BMI OBESE 1
# Predict Insurance Charges: 31270.30

# %%
y_pred
# Out:
# array([-6336.78772231])
